# %% [markdown]
# ### Έστω ότι το p value για ένα δίπλευρο έλεγχο με μηδενική υπόθεση 𝐻0: 𝜇 = 30 είναι 0.04.

# %% [markdown]
# Το p-value είναι η πιθανότητα να παρατηρήσουμε δεδομένα τουλάχιστον τόσο ακραία όσο τα δεδομένα που παρατηρήσαμε, υπό την υπόθεση ότι η μηδενική υπόθεση (H0) είναι αληθής. Σε αυτή την περίπτωση, η μηδενική υπόθεση είναι ότι η μέση τιμή μ είναι ίση με 30. Ένα p-value του 0.04 σημαίνει ότι υπάρχει πιθανότητα 4% να παρατηρήσουμε τα δεδομένα που έχουμε εάν η μέση τιμή είναι πραγματικά 30.

# %% [markdown]
# ##### a). Η τιμή 30 περιέχεται στο 95% διάστημα εμπιστοσύνης για τη μέση τιμή 𝜇; Γιατί;
# - Εάν η μηδενική υπόθεση (H0: μ = 30) είναι αληθής, τότε η τιμή 30 θα περιλαμβάνεται στο διάστημα εμπιστοσύνης του 95%. Εδώ, το p-value 0.04 είναι μικρότερο από 0.05, έτσι απορρίπτουμε τη μηδενική υπόθεση, που σημαίνει ότι η τιμή 30 δεν περιλαμβάνεται στο 95% διάστημα εμπιστοσύνης.

# %% [markdown]
# ##### b). Η τιμή 30 περιέχεται στο 90% διάστημα; Γιατί;
# - Εφόσον το p-value του 0.04 είναι μικρότερο και από αυτό το επίπεδο, πάλι απορρίπτουμε τη μηδενική υπόθεση, που σημαίνει ότι η τιμή 30 δεν περιλαμβάνεται ούτε στο 90% διάστημα εμπιστοσύνης.
